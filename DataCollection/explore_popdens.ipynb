# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (15, 15)

# %%
img = plt.imread('jpn_ppp_2020_1km_Aggregated.tif')
print(img.shape)
img = img[:,:,0]
print(img.shape)
plt.imshow(img, cmap='viridis')
plt.show()
# Out:
# (2578, 3727, 4)
# (2578, 3727)

# %%
from osgeo import gdal
ds = gdal.Open('jpn_ppp_2020_1km_Aggregated.tif')
width = ds.RasterXSize
height = ds.RasterYSize
gt = ds.GetGeoTransform()
minx = gt[0]
miny = gt[3] + width*gt[4] + height*gt[5] 
maxx = gt[0] + width*gt[1] + height*gt[2]
maxy = gt[3]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-20f499ab2449> in <module>
# ----> 1 from osgeo import gdal
#       2 ds = gdal.Open('jpn_ppp_2020_1km_Aggregated.tif')
#       3 width = ds.RasterXSize
#       4 height = ds.RasterYSize
#       5 gt = ds.GetGeoTransform()
#
# ModuleNotFoundError: No module named 'osgeo'
