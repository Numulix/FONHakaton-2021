# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
img = plt.imread('jpn_ppp_2020_1km_Aggregated.tif')
print(img.shape)
plt.imshow(img, cmap='viridis')
plt.show()
# Out:
# (2578, 3727, 4)

# %%
for x in range(4):
    print(np.mean(img[:,:,x]))
# Out:
# 3.8616096490853757
# 3.8616096490853757
# 3.8616096490853757
# 255.0
